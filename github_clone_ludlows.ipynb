# %%
import numpy
import tensorflow
import sklearn

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/ludlows/CSI-Activity-Recognition.git
# Out:
# Cloning into 'CSI-Activity-Recognition'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 13 (delta 1), reused 9 (delta 0), pack-reused 0
# Receiving objects: 100% (13/13), 33.52 KiB | 1.52 MiB/s, done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd /content/drive/MyDrive/CSI-Activity-Recognition
# Out:
# /content/drive/MyDrive/CSI-Activity-Recognition

# %%
# !ls
# Out:
# csimodel.py  img  README.md

# %%
# !tar -xzvf /content/drive/MyDrive/final_project/Dataset.tar.gz
# Out:
# Dataset/
# Dataset/._LICENSE
# Dataset/LICENSE
# Dataset/._Data
# Dataset/Data/
# Dataset/Data/._annotation_siamak_walk_5.csv
# Dataset/Data/annotation_siamak_walk_5.csv
# Dataset/Data/._annotation_walk_170303_1343_09.csv
# Dataset/Data/annotation_walk_170303_1343_09.csv
# Dataset/Data/._input_161219_sankalp_run_6.csv
# Dataset/Data/input_161219_sankalp_run_6.csv
# Dataset/Data/._annotation_pickup_170309_1237_04.csv
# Dataset/Data/annotation_pickup_170309_1237_04.csv
# Dataset/Data/._annotation_siamak_run_8.csv
# Dataset/Data/annotation_siamak_run_8.csv
# Dataset/Data/._annotation_sankalp_fall_10.csv
# Dataset/Data/annotation_sankalp_fall_10.csv
# Dataset/Data/._annotation_walk_170303_1402_18.csv
# Dataset/Data/annotation_walk_170303_1402_18.csv
# Dataset/Data/._input_walk_170308_1304_17.csv
# Dataset/Data/input_walk_170308_1304_17.csv
# Dataset/Data/._input_run_170309_1315_15.csv
# Dataset/Data/input_run_170309_1315_15.csv
# Dataset/Data/._annotation_bed_170308_1410_06.csv
# ...

# %%
# List the extracted files to ensure they are in the correct place
# !ls /content/drive/MyDrive/CSI-Activity-Recognition/Dataset/Data
# Out:
# annotation_bed_170308_1405_01.csv      input_161219_sankalp_bed_10.csv
# annotation_bed_170308_1406_02.csv      input_161219_sankalp_bed_1.csv
# annotation_bed_170308_1407_03.csv      input_161219_sankalp_bed_2.csv
# annotation_bed_170308_1408_04.csv      input_161219_sankalp_bed_3.csv
# annotation_bed_170308_1409_05.csv      input_161219_sankalp_bed_4.csv
# annotation_bed_170308_1410_06.csv      input_161219_sankalp_bed_5.csv
# annotation_bed_170308_1411_07.csv      input_161219_sankalp_bed_6.csv
# annotation_bed_170308_1412_08.csv      input_161219_sankalp_bed_7.csv
# annotation_bed_170308_1413_09.csv      input_161219_sankalp_bed_8.csv
# annotation_bed_170308_1414_10.csv      input_161219_sankalp_bed_9.csv
# annotation_bed_170308_1415_11.csv      input_161219_sankalp_fall_10.csv
# annotation_bed_170308_1416_12.csv      input_161219_sankalp_fall_1.csv
# annotation_bed_170308_1417_13.csv      input_161219_sankalp_fall_2.csv
# ...

# %%
# !python csimodel.py /content/drive/MyDrive/CSI-Activity-Recognition/Dataset/Data
# Out:
# 2024-08-02 04:03:39.171008: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:95] Opening library: /usr/local/lib/python3.10/dist-packages/tensorflow/python/platform/../../libtensorflow_cc.so.2
# 2024-08-02 04:03:39.171176: I tensorflow/core/tpu/tpu_api_dlsym_initializer.cc:119] Libtpu path is: libtpu.so
# 2024-08-02 04:03:39.229157: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Starting Extract CSI for Label bed
# Warning! Label File Dataset/Data/annotation_161219_sankalp_bed_1.csv doesn't exist.
# Warning! Label File Dataset/Data/annotation_161219_sankalp_bed_10.csv doesn't exist.
# Warning! Label File Dataset/Data/annotation_161219_sankalp_bed_2.csv doesn't exist.
# ...

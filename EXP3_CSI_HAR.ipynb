# %% [markdown]
# # CSI HAR
# - LSTM & Attention
# - Training:Validating:Testing = 6:2:2

# %% [markdown]
# ## 1. Import libraries and dataset

# %%
#importing libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import glob, os
from numpy import dstack

# Data Scaling
from sklearn.preprocessing import StandardScaler
from sklearn.base import TransformerMixin

import keras
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dropout

from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix

import seaborn as sns
from matplotlib.pyplot import figure

print('libraries have imported ')
# Out:
# libraries have imported

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/final_project/Experiment3/Data"
os.chdir(path)
results = pd.DataFrame([])
list_file = glob.glob("*.csv") #lisiting all the csv files
print(list_file)
# Out:
# ['Lying_Amp_104.csv', 'Lying_Amp_209.csv', 'Empty_Amp_197.csv', 'Lying_Amp_121.csv', 'Empty_Amp_172.csv', 'Lying_Amp_204.csv', 'Lying_Amp_17.csv', 'Lying_Amp_110.csv', 'Empty_Amp_185.csv', 'Empty_Amp_32.csv', 'Lying_Amp_123.csv', 'Lying_Amp_162.csv', 'Lying_Amp_128.csv', 'Empty_Amp_182.csv', 'Empty_Amp_254.csv', 'Empty_Amp_65.csv', 'Empty_Amp_38.csv', 'Empty_Amp_250.csv', 'Lying_Amp_201.csv', 'Empty_Amp_211.csv', 'Lying_Amp_153.csv', 'Empty_Amp_266.csv', 'Lying_Amp_174.csv', 'Lying_Amp_197.csv', 'Lying_Amp_173.csv', 'Lying_Amp_208.csv', 'Lying_Amp_179.csv', 'Lying_Amp_186.csv', 'Empty_Amp_54.csv', 'Empty_Amp_25.csv', 'Lying_Amp_184.csv', 'Lying_Amp_119.csv', 'Lying_Amp_124.csv', 'Empty_Amp_37.csv', 'Empty_Amp_239.csv', 'Lying_Amp_127.csv', 'Empty_Amp_263.csv', 'Lying_Amp_106.csv', 'Empty_Amp_221.csv', 'Empty_Amp_61.csv', 'Empty_Amp_85.csv', 'Lying_Amp_166.csv', 'Empty_Amp_189.csv', 'Empty_Amp_92.csv', 'Empty_Amp_215.csv', 'Empty_Amp_170.csv', 'Empty_Amp_2.csv', 'Empty_Amp_28.csv', 'Empty_Amp_258.csv', 'Empty_Amp_238.csv', 'Empty_Amp_96.csv', 'Empty_Amp_257.csv', 'Empty_Amp_19.csv', 'Lying_Amp_114.csv', 'Empty_Amp_60.csv', 'Empty_Amp_256.csv', 'Empty_Amp_7.csv', 'Lying_Amp_103.csv', 'Empty_Amp_35.csv', 'Lying_Amp_180.csv', 'Lying_Amp_192.csv', 'Lying_Amp_176.csv', 'Empty_Amp_213.csv', 'Empty_Amp_246.csv', 'Lying_Amp_168.csv', 'Lying_Amp_130.csv', 'Empty_Amp_24.csv', 'Empty_Amp_83.csv', 'Empty_Amp_166.csv', 'Lying_Amp_189.csv', 'Lying_Amp_139.csv', 'Lying_Amp_109.csv', 'Empty_Amp_17.csv', 'Empty_Amp_46.csv', 'Empty_Amp_217.csv', 'Empty_Amp_191.csv', 'Empty_Amp_69.csv', 'Empty_Amp_173.csv', 'Empty_Amp_233.csv', 'Empty_Amp_66.csv', 'Empty_Amp_58.csv', 'Lying_Amp_12.csv', 'Empty_Amp_22.csv', 'Empty_Amp_214.csv', 'Empty_Amp_21.csv', 'Empty_Amp
# %% [markdown]
# ## 2. Preprocessing

# %%
# function for reading CSV files
def reading_file(activity_csv):
    results = []
    for i in range(len(activity_csv)):
        df = pd.read_csv(activity_csv[i])
        results.append(df.values)
    return results

# %%
#Classify each csv files by its activity
empty_csv = [i for i in list_file if i.startswith('Empty')]
lying_csv = [i for i in list_file if i.startswith('Lying')]
sitting_csv = [i for i in list_file if i.startswith('Sitting')]
standing_csv = [i for i in list_file if i.startswith('Standing')]
walking_csv = [i for i in list_file if i.startswith('Walking')]

# %%
#calling reading_file function
empty = reading_file(empty_csv)
lying = reading_file(lying_csv)
sitting = reading_file(sitting_csv)
standing = reading_file(standing_csv)
walking = reading_file(walking_csv)

# %% [markdown]
# ### Labelling

# %%
#function for labeling the samples
def label(activity, label):
    list_y = []
    for i in range(len(activity)):
        list_y.append(label)
    return np.array(list_y).reshape(-1, 1)

# %%
walking_label = label(walking, 'walking')
empty_label = label(empty, 'empty')
lying_label = label(lying, 'lying')
sitting_label = label(sitting, 'sitting')
standing_label = label(standing, 'standing')

# %%
#concatenate all the samples into one np array
array_tuple = (empty, lying, sitting,standing, walking)
data_X = np.vstack(array_tuple)

#concatenate all the label into one array
label_tuple = (empty_label, lying_label, sitting_label,standing_label,  walking_label)
data_y = np.vstack(label_tuple)

#randomise the sample
from sklearn.utils import shuffle
data_X, data_y= shuffle(data_X, data_y)

# %% [markdown]
# ### Splitting
#
# Training, Validating, and Testing

# %%
from sklearn.model_selection import train_test_split
X = data_X
y = data_y

# split the data into training + validation (80%) and test (20%)
X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# Split the training + validation set into training (60%) and validation (20%)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42)

# %% [markdown]
# ### Standardisation

# %%
# Standardisation is necessary when using neural network

class Standard_Scaler(TransformerMixin):
    def __init__(self, **kwargs):
        self._scaler = StandardScaler(copy=True, **kwargs)
        self._orig_shape = None

    def fit(self, X, **kwargs):
        X = np.array(X)
        # Save the original shape to reshape the flattened X later
        # back to its original shape
        if len(X.shape) > 1:
            self._orig_shape = X.shape[1:]
        X = self._flatten(X)
        self._scaler.fit(X, **kwargs)
        return self

    def transform(self, X, **kwargs):
        X = np.array(X)
        X = self._flatten(X)
        X = self._scaler.transform(X, **kwargs)
        X = self._reshape(X)
        return X

    def _flatten(self, X):
        # Reshape X to 2 dimensions
        if len(X.shape) > 2:
            n_dims = np.prod(self._orig_shape)
            X = X.reshape(-1, n_dims)
        return X

    def _reshape(self, X):
        # Reshape X back to it's original shape
        if len(X.shape) >= 2:
            X = X.reshape(-1, *self._orig_shape)
        return X

# %%
sc = Standard_Scaler()
X_train = sc.fit_transform(X_train)
X_val = sc.transform (X_val)
X_test = sc.transform (X_test)

# %% [markdown]
# ### OneHotEncoder

# %%
#Encode categorical features (Activity Names) as a one-hot numeric array.
from sklearn.preprocessing import OneHotEncoder

en = OneHotEncoder()
y_train_en = OneHotEncoder().fit_transform(y_train.reshape(-1, 1)).toarray()
y_val_en = OneHotEncoder().fit_transform(y_val.reshape(-1, 1)).toarray()
y_test_en = OneHotEncoder().fit_transform(y_test.reshape(-1, 1)).toarray()

# %%
(X_train.shape, X_val.shape, X_test.shape, y_train_en.shape, y_val_en.shape, y_test_en.shape)
# Out:
# ((720, 500, 256),
#  (240, 500, 256),
#  (241, 500, 256),
#  (720, 5),
#  (240, 5),
#  (241, 5))

# %% [markdown]
# ## 3. LSTM & Attention

# %%
# !pip install tensorflow-addons
import tensorflow_addons as tfa
# Out:
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.10/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (24.1)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.10/dist-packages (from tensorflow-addons) (2.13.3)

# %%
class LSTMWithAttention(tf.keras.Model):
    def __init__(self, lstm_units, dense_units, num_classes):
        super(LSTMWithAttention, self).__init__()
        self.lstm = tf.keras.layers.LSTM(units=lstm_units, return_sequences=True, input_shape= X_train[-2,:].shape)
        self.attention = tf.keras.layers.Attention()
        self.flatten = tf.keras.layers.Flatten()
        self.dropout = tf.keras.layers.Dropout(rate=0.5)
        self.dense = tf.keras.layers.Dense(units=dense_units, activation='relu')
        self.final_dense = tf.keras.layers.Dense(units=num_classes, activation='softmax')

    def call(self, inputs):
        lstm_out = self.lstm(inputs)
        attention_out = self.attention([lstm_out, lstm_out])
        combined_out = self.flatten(attention_out)
        dropout_out = self.dropout(combined_out)
        dense_out = self.dense(dropout_out)
        return self.final_dense(dense_out)

# %%
# Create an instance of the model
activity_model = LSTMWithAttention(lstm_units=64, dense_units=32, num_classes=y_train_en.shape[1])

lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-8 * 10**(epoch / 20))
opt = keras.optimizers.Adam(learning_rate=1e-8)

# Compile the model
activity_model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of the model
activity_model.build(input_shape=(None, X_train.shape[1], X_train.shape[2]))
activity_model.summary()
# Out:
# Model: "lstm_with_attention_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               multiple                  82176
#
#  attention_7 (Attention)     multiple                  0
#
#  flatten_7 (Flatten)         multiple                  0
#
#  dropout_7 (Dropout)         multiple                  0
#
#  dense_14 (Dense)            multiple                  1024032
#
#  dense_15 (Dense)            multiple                  165
#
# =================================================================
# Total params: 1106373 (4.22 MB)
# Trainable params: 1106373 (4.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model_history = activity_model.fit(X_train, y_train_en, epochs= 100, validation_data=(X_val, y_val_en),  batch_size=16, callbacks = [lr_schedule])
# Out:
# Epoch 1/100
# 45/45 [==============================] - 10s 192ms/step - loss: 1.6722 - accuracy: 0.1778 - val_loss: 1.6577 - val_accuracy: 0.1917 - lr: 1.0000e-08
# Epoch 2/100
# 45/45 [==============================] - 8s 176ms/step - loss: 1.6672 - accuracy: 0.1750 - val_loss: 1.6567 - val_accuracy: 0.1958 - lr: 1.1220e-08
# Epoch 3/100
# 45/45 [==============================] - 8s 174ms/step - loss: 1.6664 - accuracy: 0.2028 - val_loss: 1.6557 - val_accuracy: 0.1958 - lr: 1.2589e-08
# Epoch 4/100
# 45/45 [==============================] - 8s 183ms/step - loss: 1.6822 - accuracy: 0.1708 - val_loss: 1.6546 - val_accuracy: 0.1958 - lr: 1.4125e-08
# Epoch 5/100
# 45/45 [==============================] - 8s 180ms/step - loss: 1.6464 - accuracy: 0.2083 - val_loss: 1.6533 - val_accuracy: 0.1958 - lr: 1.5849e-08
# Epoch 6/100
# 45/45 [==============================] - 8s 172ms/step - loss: 1.6600 - accuracy: 0.1917 - val_loss: 1.6518 - val_accuracy: 0.1958 - lr: 1.7783e-08
# Epoch 7/100
step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.1001 - val_accuracy: 0.9708 - lr: 5.6234e-05
# Epoch 77/100
# 45/45 [==============================] - 8s 173ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.0958 - val_accuracy: 0.9667 - lr: 6.3096e-05
# Epoch 78/100
# 45/45 [==============================] - 8s 170ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.0909 - val_accuracy: 0.9667 - lr: 7.0795e-05
# Epoch 79/100
# 45/45 [==============================] - 8s 176ms/step - loss: 0.0097 - accuracy: 1.0000 - val_loss: 0.0946 - val_accuracy: 0.9667 - lr: 7.9433e-05
# Epoch 80/100
# 45/45 [==============================] - 8s 175ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 0.9708 - lr: 8.9125e-05
# Epoch 81/100
# 45/45 [==============================] - 8s 174ms/step - loss: 0.0068 - accuracy: 1.0000 - val_loss: 0.0857 - val_accuracy: 0.9667 - lr: 1.0000e-04
# Epoch 82/100
# 45/45 [==============================] - 8s 177ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 0.9667 - lr: 1.1220e-04
# Epoch 83/100
# 45/45 [==============================] - 8s 173ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.0850 - val_accuracy: 0.9667 - lr: 1.2589e-04
# Epoch 84/100
# 45/45 [==============================] - 8s 180ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0822 - val_accuracy: 0.9750 - lr: 1.4125e-04
# Epoch 85/100
# 45/45 [==============================] - 8s 176ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0798 - val_accuracy: 0.9792 - lr: 1.5849e-04
# Epoch 86/100
# 45/45 [==============================] - 8s 172ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0773 - val_accuracy: 0.9792 - lr: 1.7783e-04
# Epoch 87/100
# 45/45 [==============================] - 8s 179ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0763 - val_accuracy: 0.9750 - lr: 1.9953e-04
# Epoch 88/100
# 45/45 [==============================] - 8s 175ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0778 - val_accuracy: 0.9833 - lr: 2.2387e-04
# Epoch 89/100
# 45/45 [==============================] - 8s 176ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0760 - val_accuracy: 0.9833 - lr: 2.5119e-04
# Epoch 90/100
# 45/45 [==============================] - 8s 177ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0749 - val_accuracy: 0.9833 - lr: 2.8184e-04
# Epoch 91/100
# 45/45 [==============================] - 8s 171ms/step - loss: 9.8847e-04 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9833 - lr: 3.1623e-04
# Epoch 92/100
# 45/45 [==============================] - 8s 177ms/step - loss: 7.7028e-04 - accuracy: 1.0000 - val_loss: 0.0723 - val_accuracy: 0.9833 - lr: 3.5481e-04
# Epoch 93/100
# 45/45 [==============================] - 8s 176ms/step - loss: 6.0793e-04 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9833 - lr: 3.9811e-04
# Epoch 94/100
# 45/45 [==============================] - 8s 171ms/step - loss: 5.0933e-04 - accuracy: 1.0000 - val_loss: 0.0746 - val_accuracy: 0.9833 - lr: 4.4668e-04
# Epoch 95/100
# 45/45 [==============================] - 8s 178ms/step - loss: 4.0792e-04 - accuracy: 1.0000 - val_loss: 0.0741 - val_accuracy: 0.9833 - lr: 5.0119e-04
# Epoch 96/100
# 45/45 [==============================] - 8s 171ms/step - loss: 3.8594e-04 - accuracy: 1.0000 - val_loss: 0.0758 - val_accuracy: 0.9833 - lr: 5.6234e-04
# Epoch 97/100
# 45/45 [==============================] - 8s 174ms/step - loss: 3.6076e-04 - accuracy: 1.0000 - val_loss: 0.0733 - val_accuracy: 0.9833 - lr: 6.3096e-04
# Epoch 98/100
# 45/45 [==============================] - 8s 173ms/step - loss: 2.6212e-04 - accuracy: 1.0000 - val_loss: 0.0725 - val_accuracy: 0.9833 - lr: 7.0795e-04
# Epoch 99/100
# 45/45 [==============================] - 8s 171ms/step - loss: 2.2698e-04 - accuracy: 1.0000 - val_loss: 0.0761 - val_accuracy: 0.9833 - lr: 7.9433e-04
# Epoch 100/100
# 45/45 [==============================] - 8s 176ms/step - loss: 1.7268e-04 - accuracy: 1.0000 - val_loss: 0.0760 - val_accuracy: 0.9833 - lr: 8.9125e-04

# %%
scores = activity_model.evaluate(X_val, y_val_en)
print(f"Validation set performance: {scores}")
# Out:
# 8/8 [==============================] - 1s 85ms/step - loss: 0.0760 - accuracy: 0.9833
# Validation set performance: [0.07603298872709274, 0.9833333492279053]

# %%
# Exponential Decay Plot
figure(figsize=(12, 8))
plt.semilogx(model_history.history["lr"], np.array(model_history.history["loss"]))
sns.set(font_scale=1.5)
plt.ylabel('Loss Value')
plt.xlabel('Learning Rate')
plt.title('Exponential Decay plot')
plt.show()

# %% [markdown]
# ### Model traing after choosing best learning rate

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('val_accuracy')>0.98):
            print("\nAccuracy has reached to threshold (98%) so stopping training!")
            self.model.stop_training = True

callbacks = myCallback()

earlystopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)

model = LSTMWithAttention(lstm_units=64, dense_units=32, num_classes=y_train_en.shape[1])

opt = keras.optimizers.Adam(learning_rate=1e-4)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

model.build(input_shape=(None, X_train.shape[1], X_train.shape[2]))

# %% [markdown]
# ## Model Summary

# %%
model.summary()
# Out:
# Model: "lstm_with_attention_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               multiple                  82176
#
#  attention_8 (Attention)     multiple                  0
#
#  flatten_8 (Flatten)         multiple                  0
#
#  dropout_8 (Dropout)         multiple                  0
#
#  dense_16 (Dense)            multiple                  1024032
#
#  dense_17 (Dense)            multiple                  165
#
# =================================================================
# Total params: 1106373 (4.22 MB)
# Trainable params: 1106373 (4.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 4. LSTM Model Training

# %%
history = model.fit(X_train, y_train_en, epochs= 50, batch_size=32, validation_data=(X_val, y_val_en), callbacks = [callbacks, earlystopping])
# Out:
# Epoch 1/50
# 23/23 [==============================] - 9s 317ms/step - loss: 0.7536 - accuracy: 0.7292 - val_loss: 0.4194 - val_accuracy: 0.8500
# Epoch 2/50
# 23/23 [==============================] - 7s 294ms/step - loss: 0.2477 - accuracy: 0.9306 - val_loss: 0.2076 - val_accuracy: 0.9500
# Epoch 3/50
# 23/23 [==============================] - 6s 279ms/step - loss: 0.1310 - accuracy: 0.9736 - val_loss: 0.1500 - val_accuracy: 0.9583
# Epoch 4/50
# 23/23 [==============================] - 7s 296ms/step - loss: 0.0663 - accuracy: 0.9889 - val_loss: 0.1181 - val_accuracy: 0.9708
# Epoch 5/50
# 23/23 [==============================] - 7s 289ms/step - loss: 0.0428 - accuracy: 0.9944 - val_loss: 0.0964 - val_accuracy: 0.9750
# Epoch 6/50
# 23/23 [==============================] - 7s 286ms/step - loss: 0.0293 - accuracy: 0.9986 - val_loss: 0.0892 - val_accuracy: 0.9750
# Epoch 7/50
# 23/23 [==============================] - 6s 275ms/step - loss: 0.0204 - accuracy: 0.9986 - val_loss: 0.0890 - val_accuracy: 0.9750
# Epoch 8/50
# 23/23 [==============================] - 7s 286ms/step - loss: 0.0152 - accuracy: 0.9986 - val_loss: 0.0768 - val_accuracy: 0.9750
# Epoch 9/50
# 23/23 [==============================] - 6s 276ms/step - loss: 0.0117 - accuracy: 0.9986 - val_loss: 0.0739 - val_accuracy: 0.9750
# Epoch 10/50
# 23/23 [==============================] - 7s 288ms/step - loss: 0.0097 - accuracy: 0.9986 - val_loss: 0.0670 - val_accuracy: 0.9792
# Epoch 11/50
# 23/23 [==============================] - 6s 275ms/step - loss: 0.0073 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9792
# Epoch 12/50
# 23/23 [==============================] - 7s 287ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0655 - val_accuracy: 0.9792
# Epoch 13/50
# 23/23 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 1.0000
# Accuracy has reached to threshold (98%) so stopping training!
# 23/23 [==============================] - 6s 279ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.0648 - val_accuracy: 0.9833

# %% [markdown]
# ## 5. Model Evaluation

# %%
scores = model.evaluate(X_val, y_val_en)
print(f"Validation set performance: {scores}")
# Out:
# 8/8 [==============================] - 1s 105ms/step - loss: 0.0648 - accuracy: 0.9833
# Validation set performance: [0.06479925662279129, 0.9833333492279053]

# %%
y_pred = model.predict(X_test) #prediction on test data set
# Out:
# 8/8 [==============================] - 1s 87ms/step

# %%
model.evaluate(X_test, y_test_en)
# Out:
# 8/8 [==============================] - 1s 89ms/step - loss: 0.0303 - accuracy: 0.9959
# [0.03034287318587303, 0.9958506226539612]

# %% [markdown]
# # III. Result

# %% [markdown]
# # Model History plot

# %%
# plot history
figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='validation loss')
plt.ylabel('Loss Value')
plt.xlabel('No of Epoches')
plt.legend()
plt.show()

# %%
# plot history
figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='train_accuray')
plt.plot(history.history['val_accuracy'], label='validation_accuray')
plt.ylabel('Accuracy')
plt.xlabel('No of Epoches')
plt.legend()
plt.show()

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(np.argmax(y_test_en, axis=1), np.argmax(y_pred, axis=1))
index = ['Empty', 'Lying', 'Sitting','Standing','Walking']
columns = ['Empty', 'Lying', 'Sitting','Standing','Walking']
df_cm = pd.DataFrame(confusion_matrix,columns,index)

# %%
sns.set(font_scale=1.5)
figure(figsize=(10, 5))
sns.heatmap(df_cm, annot=True, cmap='Blues', linewidths=0.2,annot_kws={"fontsize":15})
plt.title("Confusion Matrix", fontsize=16)
plt.ylabel('True Activities', fontsize=16)
plt.xlabel('Predicted Activities', fontsize=16)
# Out:
# Text(0.5, 13.249999999999995, 'Predicted Activities')

# %%
# Classification Report
from sklearn.metrics import classification_report
target_names = ['Empty', 'Lying', 'Sitting','Standing','Walking']
print(classification_report(np.argmax(y_test_en, axis=1), np.argmax(y_pred, axis=1), target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#        Empty       1.00      0.98      0.99        56
#        Lying       0.99      1.00      0.99        67
#      Sitting       1.00      1.00      1.00        37
#     Standing       1.00      1.00      1.00        40
#      Walking       1.00      1.00      1.00        41
#
#     accuracy                           1.00       241
#    macro avg       1.00      1.00      1.00       241
# weighted avg       1.00      1.00      1.00       241
